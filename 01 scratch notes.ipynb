# %% [markdown]
# which hosts the databricks web application
#
# ~ databricks account - control plane

# %% [markdown]
# describe databricks lakehouse
#
# ~ single, flexible, high-performance system that supports data, analytics and machine learning workload

# %% [markdown]
# benefits of using databricks lakehouse platform
#
# ~ ability to support batch and streaming workloads

# %% [markdown]
# data analysis team's reports being different from data engineering team's report. the leader believes the silo nature of their organization's dat engineering and analysis architecture is to blame. which of the following describes how a data lakehouse could alleviate this issue?
#
# ~ both teams would use the same source fo truth for their work

# %% [markdown]
# describe the storage organization of a delta table
#
# ~ delta table are stored in a collection of files that contain data history, metadata, and other attributes

# %% [markdown]
# primary format for tha data files
#
# ~ parquet

# %% [markdown]
# command to compact small data files of a delta table into larger ones?
#
# ~ optimize

# %% [markdown]
# statements about delta lake?
#
# ~ provides ACID transaction guarantees
#
# ~ provides scalable data and metadata handling
#
# ~ provides audit history and timme travel
#
# ~ supports unified streaming and batch data processing

# %% [markdown]
# vacuum default retention?
#
# ~ 7 days

# %% [markdown]
# databricks repos git functionality
#
# ~ clone , push , pull from remote git
#
# ~ create and manage branch
#
# ~ create notebooks , edit notebooks and other files
#
# ~ visually compare difference upon commit

# %% [markdown]
# git provider tasks
#
# ~ create pull request
#
# ~ resolve merge conflicts
#
# ~ merge or delete branches
#
# ~ rebase branch

# %% [markdown]
# pyspark table access
#
# ~ spark.table("table_name")

# %% [markdown]
# command that will return the location of database
#
# ~ DESCRIBE DATABASE database_name;

# %% [markdown]
# create table syntax
#
# CREATE OR REPLACE TABLE table_name
# LOCATION "."
# PARTITIONED BY column_name
# COMMENT "message"
# AS

# %% [markdown]
# benefits provided by the array functions from SPARK SQL?
#
# ~ ability to work with complex, nested data injested from JSON files

# %% [markdown]
# command used to write data into a delta table while avoiding duplicate methods
#
# ~ MERGE

# %% [markdown]
# SQL UDF syntax
#
# ```
# CREATE OR REPLACE FUNCTION city_table (city STRING)
# RETURNS STRING
# RETURN
#   CASE
#     WHEN "brooklyn" THEN "new york"
#     ELSE city
#   END;
# ```

# %% [markdown]
# tools used by loader to process data incrementally
#
# ~ spark structured streaming

# %% [markdown]
# in designing data pipeline, to identify which files are new since the previous run in the pipeline and setup the pipeline to only ingest those new files with each run. this tool can solve this problem.
#
# ~ auto loader

# %% [markdown]
# describe the relationship between GOLD and SILVER table?
#
# ~ gold tables are more likely to contain aggregations than SILVER tables

# %% [markdown]
# describe the relationship between BRONZE and RAW data?
#
# ~ bronze tables contain raw data with schema applied

# %% [markdown]
# in order for structured streaming to reliably tranck the exact progress of the processing so that it can handly any kind of failure by restarting and/or reprocessing. which approach is used by spark to record the offset range of the data being processed in each trigger?
#
# ~ checkpointing and write-ahead logs

# %% [markdown]
# to automate the process of monitoring the quality level. this tool can be use.
#
# ~ delta live tables

# %% [markdown]
# the table is configured to run in production using continious pipeline mode. assuming previously unprocessed data exists and all definitions are valid. what is the expected outcome after clicking start to update the pipeline.
#
# ~ all datasets will be updated at st intervals until the pipeline is shutdown. the compute resources will be deployed for the update and terminated when the pipeline is stored.

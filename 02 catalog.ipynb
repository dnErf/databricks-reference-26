# %% [markdown]
# ### create schema on default catalog (workspace)

# %%
# %sql
USE CATALOG i26;

CREATE SCHEMA IF NOT EXISTS raw;
CREATE SCHEMA IF NOT EXISTS silver;

# %%
# %sql
SHOW SCHEMAS;

# %%
# %sql
USE CATALOG i26;
USE SCHEMA raw;

CREATE EXTERNAL VOLUME IF NOT EXISTS operation_data
LOCATION 'r2://i26@863dd3cbd03e1913586c35b5fb9dfa3f.r2.cloudflarestorage.com/databricks/raw/operation_data/';
